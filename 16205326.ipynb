# %% [markdown]
# # Visualisation 1 2 and 3 dataset manipulation

# %%
#importing libraries 
import csv
import pandas as pd

# %% [markdown]
# ## Reading the intial dataset

# %%
data=pd.read_csv("../datasets/initial_dataset.csv")
data
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000011046  Community Film Project: The Art of Neighborhoo...
# ...            ...                                                ...
# 378656   999976400  ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 378657   999977640                                          The Tribe
# 378658   999986353  Walls of Remedy- New lesbian Romantic Comedy f...
# 378659   999987933                           BioDefense Education Kit
# 378660   999988282                  Nou Renmen Ayiti!  We Love Haiti!
#
#                category main_category currency    deadline     goal  \
# ...

# %% [markdown]
# ## Cleaning the initial dataset
# Changing all non sccessful statuses to failed, as there is no need for details

# %%
cleaned_data=data[['category','state','usd_goal_real','country','launched']]#.to_csv("../datasets/visualisation1.csv")


def remove_all_not_successful(row):
    if row.state=='successful':
        return 'successful'
    else:
        return 'fail'

cleaned_data['state']=cleaned_data.apply(lambda row: remove_all_not_successful(row), axis=1)
print(cleaned_data[169:170])
cleaned_data.loc[cleaned_data['country'] == 'N,0"', 'country'] = "Not Specified"

cleaned_data[0:10]
# Out:
#          category state  usd_goal_real country             launched
# 169  Film & Video  fail         6500.0    N,0"  2014-08-06 21:28:36
# /Users/mikhailyankelevich/Desktop/CS_UCD/CS/Year_3/visualisation/assignments/data/venv/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/mikhailyankelevich/Desktop/CS_UCD/CS/Year_3/visualisation/assignments/data/venv/lib/python3.7/site-packages/pandas/core/indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# ## Cleaning and aggregating data for the visualisation 1

# %%
vis1=cleaned_data[['category', 'state']]
vis1['count']=0
 

vis1 = vis1.groupby(['category', 'state']).count()
# Out:
# /Users/mikhailyankelevich/Desktop/CS_UCD/CS/Year_3/visualisation/assignments/data/venv/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# saving data for the visualisation 1

# %%
vis1.to_csv("../datasets/vis1.csv")
print(vis1)
# Out:
#                         count
# category    state
# 3D Printing fail          441
#             successful    242
# Academic    fail          728
#             successful    188
# Accessories fail         2092
# ...                       ...
# World Music successful    922
# Young Adult fail          649
#             successful    172
# Zines       fail          212
#             successful    179
#
# [318 rows x 1 columns]

# %% [markdown]
# ## Cleaning and aggregating and saving data for the visualisation 2

# %%
vis2=cleaned_data[['category', 'country', 'usd_goal_real']]
vis2 = vis2.groupby(['category', 'country']).median()
vis2.to_csv("../datasets/vis2.csv")
print(vis2)
# Out:
#                      usd_goal_real
# category    country
# 3D Printing AT           21528.060
#             AU            7538.070
#             BE            3214.055
#             CA           11765.010
#             CH           41187.860
# ...                            ...
# Zines       MX            3160.560
#             NL            5355.180
#             NZ            2111.450
#             SE            5430.530
#             US            2870.000
#
# [2762 rows x 1 columns]

# %% [markdown]
# ## Cleaning and aggregating and saving data for the visualisation 3

# %%
vis3=cleaned_data[['launched']]


datetimes = pd.to_datetime(vis3['launched'])
vis3['year'] = datetimes.dt.year 
vis3['month'] = datetimes.dt.month

# creating sorter value
vis3['sorter']= vis3['year']*100+vis3['month']


#creating string representation of time
vis3['year']=vis3['year'].astype(str)
vis3['month']=vis3['month'].astype(str)
vis3['launched'] = vis3['year']+"-"+vis3['month']


vis3=vis3[['launched','sorter']]

vis3 = vis3.sort_values('sorter')

vis3.to_csv("../datasets/vis3.csv")
print(vis3)
# Out:
# /Users/mikhailyankelevich/Desktop/CS_UCD/CS/Year_3/visualisation/assignments/data/venv/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /Users/mikhailyankelevich/Desktop/CS_UCD/CS/Year_3/visualisation/assignments/data/venv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...
